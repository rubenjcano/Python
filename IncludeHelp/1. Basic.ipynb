# %% [markdown]
# https://www.includehelp.com/python/basic-programs.aspx

# %% [markdown]
# Exercise 1: How to print spaces in Python?

# %% [markdown]
# Exercise 2: Printing different messages using different variations of print() method
